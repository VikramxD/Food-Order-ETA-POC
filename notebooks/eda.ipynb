# %%
import numpy as np
import polars as pl
import matplotlib.pylab as plt
import seaborn as sns
import pandas as pd

# %%
dataset_path = '/Users/vicariousvision/Analytics Stuff/amazon_ml_challenge/data/processed/dataset_1.csv'

# %%
dataset = pd.read_csv(dataset_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/vicariousvision/Analytics Stuff/amazon_ml_challenge/notebooks/eda.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/vicariousvision/Analytics%20Stuff/amazon_ml_challenge/notebooks/eda.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> dataset = pd.read_csv(dataset_path)
#
# NameError: name 'pd' is not defined

# %%
dataset.head()
# Out:
# shape: (5, 21)
# ┌─────┬──────────┬────────────┬────────────┬─────┬────────────┬──────────┬────────────┬────────────┐
# │     ┆ Unnamed: ┆ 0          ┆ 1          ┆ ... ┆ 15         ┆ 16       ┆ 17         ┆ 18         │
# │ --- ┆ 0        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ ---      ┆ ---        ┆ ---        │
# │ i64 ┆ ---      ┆ str        ┆ str        ┆     ┆ str        ┆ str      ┆ str        ┆ str        │
# │     ┆ str      ┆            ┆            ┆     ┆            ┆          ┆            ┆            │
# ╞═════╪══════════╪════════════╪════════════╪═════╪════════════╪══════════╪════════════╪════════════╡
# │ 0   ┆ ID       ┆ Delivery_p ┆ Delivery_p ┆ ... ┆ multiple_d ┆ Festival ┆ City       ┆ Time_taken │
# │     ┆          ┆ erson_ID   ┆ erson_Age  ┆     ┆ eliveries  ┆          ┆            ┆ (min)      │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# ...

# %%
sample_submission_path = '/Users/vicariousvision/Analytics Stuff/amazon_ml_challenge/data/raw/dataset/sample_submission.csv'

# %%
sample_submission = pd.read_csv(sample_submission_path)

# %%
sample_submission
# Out:
#        ID  Time_taken (min)
# 0  0x7faf              25.0
# 1  0x4607              24.0
# 2  0xb379              33.0
# 3  0x7804              19.0
# 4  0x20f7              42.0

# %%
dataset.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/vicariousvision/Analytics Stuff/amazon_ml_challenge/notebooks/eda.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/vicariousvision/Analytics%20Stuff/amazon_ml_challenge/notebooks/eda.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> dataset.info()
#
# AttributeError: 'DataFrame' object has no attribute 'info'
